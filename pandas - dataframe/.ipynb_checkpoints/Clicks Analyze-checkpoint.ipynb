# %% [markdown]
# # Análise de clicks
# Está análise foi realizada na especialização em Big Data do Coursera. O objetivo da atividade é explorar as funcionalidades do DataFrame.
#
# Algumas das operações testadas não foram incluidas neste arquivo.

# %%
import pandas

# %%
buyclicksDF = pandas.read_csv("buy-clicks.csv")

# %% [markdown]
# #### Exibindo os dados carregados no dataframe:

# %%
buyclicksDF
# Out:
#                 timestamp   txId  userSessionId  team  userId  buyId  price
# 0     2016-05-26 15:36:54   6004           5820     9    1300      2    3.0
# 1     2016-05-26 15:36:54   6005           5775    35     868      4   10.0
# 2     2016-05-26 15:36:54   6006           5679    97     819      5   20.0
# 3     2016-05-26 16:36:54   6067           5665    18     121      2    3.0
# 4     2016-05-26 17:06:54   6093           5709    11    2222      5   20.0
# 5     2016-05-26 17:06:54   6094           5798    77    1304      5   20.0
# 6     2016-05-26 18:06:54   6155           5920     9    1027      5   20.0
# 7     2016-05-26 18:06:54   6156           5697    35    2199      2    3.0
# 8     2016-05-26 18:36:54   6183           5893    64    1544      5   20.0
# 9     2016-05-26 18:36:54   6184           5697    35    2199      1    2.0
# 10    2016-05-26 19:36:54   6243           5659    13    1623      4   10.0
# ...

# %%
buyclicksDF.head(5)
# Out:
#              timestamp  txId  userSessionId  team  userId  buyId  price
# 0  2016-05-26 15:36:54  6004           5820     9    1300      2    3.0
# 1  2016-05-26 15:36:54  6005           5775    35     868      4   10.0
# 2  2016-05-26 15:36:54  6006           5679    97     819      5   20.0
# 3  2016-05-26 16:36:54  6067           5665    18     121      2    3.0
# 4  2016-05-26 17:06:54  6093           5709    11    2222      5   20.0

# %%
buyclicksDF.shape
# Out:
# (2947, 7)

# %%
buyclicksDF[['price', 'userId']].head(5)
# Out:
#    price  userId
# 0    3.0    1300
# 1   10.0     868
# 2   20.0     819
# 3    3.0     121
# 4   20.0    2222

# %%
buyclicksDF['price'].sum()
# Out:
# 21407.0

# %%
buyclicksDF['price'].mean()
# Out:
# 7.263997285374957

# %% [markdown]
# #### Instâncias do dataset que possuem preço maior do que 3:

# %%
buyclicksDF[buyclicksDF['price']<3]
# Out:
#                 timestamp   txId  userSessionId  team  userId  buyId  price
# 9     2016-05-26 18:36:54   6184           5697    35    2199      1    2.0
# 14    2016-05-26 20:06:54   6271           5706     9    1652      0    1.0
# 15    2016-05-26 20:36:54   6292           5921     2     518      0    1.0
# 18    2016-05-26 22:06:54   6395           5880    35    2146      1    2.0
# 19    2016-05-26 22:36:54   6411           6230    77    1457      0    1.0
# 21    2016-05-26 23:36:54   6458           5698     9    1143      1    2.0
# 22    2016-05-27 00:06:54   6473           5910    69    1162      1    2.0
# 31    2016-05-27 04:36:54   6684           5652    11     937      0    1.0
# 34    2016-05-27 06:06:54   6752           5811    97     649      0    1.0
# 39    2016-05-27 08:06:54   6866           5698     9    1143      1    2.0
# 45    2016-05-27 11:36:54   7031           6993    22    1022      0    1.0
# ...

# %% [markdown]
# #### Combinando datasets

# %%
adClicksDF = pandas.read_csv("ad-clicks.csv")
mergeDF = adClicksDF.merge(buyclicksDF, on='userId')

# %%
mergeDF.head(5)
# Out:
#            timestamp_x  txId_x  userSessionId_x  teamId  userId  adId  \
# 0  2016-05-26 15:13:22    5974             5809      27     611     2
# 1  2016-05-26 15:13:22    5974             5809      27     611     2
# 2  2016-05-26 15:13:22    5974             5809      27     611     2
# 3  2016-05-26 15:13:22    5974             5809      27     611     2
# 4  2016-05-26 15:13:22    5974             5809      27     611     2
#
#     adCategory          timestamp_y  txId_y  userSessionId_y  team  buyId  \
# 0  electronics  2016-05-30 13:06:54   11058             9769    27      1
# 1  electronics  2016-06-03 18:36:54   17005            15910    27      4
# 2  electronics  2016-06-07 12:06:54   22930            20644    27      5
# 3  electronics  2016-06-11 02:06:54   29101            26524    27      4
# 4  electronics  2016-06-13 02:36:54   32796            26524    27      4
#
#    price
# 0    2.0
# 1   10.0
# 2   20.0
# 3   10.0
# 4   10.0
